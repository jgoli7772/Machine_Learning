# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.datasets import load_iris
from matplotlib import pyplot as plt

# %%
data1=pd.read_csv("test.csv")
data1
# Out:
#      pclass                                          name     sex   age  \
# 0         3                              Kelly, Mr. James    male  34.5
# 1         3              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2         2                     Myles, Mr. Thomas Francis    male  62.0
# 3         3                              Wirz, Mr. Albert    male  27.0
# 4         3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..      ...                                           ...     ...   ...
# 413       3                            Spector, Mr. Woolf    male   NaN
# 414       1                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415       3                  Saether, Mr. Simon Sivertsen    male  38.5
# 416       3                           Ware, Mr. Frederick    male   NaN
# 417       3                      Peter, Master. Michael J    male   NaN
#
#      sibsp  parch              ticket      fare cabin embarked
# ...

# %%
data1.shape
# Out:
# (418, 10)

# %%
data1.describe()
# Out:
#            pclass         age       sibsp       parch        fare
# count  418.000000  332.000000  418.000000  418.000000  417.000000
# mean     2.265550   30.272590    0.447368    0.392344   35.627188
# std      0.841838   14.181209    0.896760    0.981429   55.907576
# min      1.000000    0.170000    0.000000    0.000000    0.000000
# 25%      1.000000   21.000000    0.000000    0.000000    7.895800
# 50%      3.000000   27.000000    0.000000    0.000000   14.454200
# 75%      3.000000   39.000000    1.000000    0.000000   31.500000
# max      3.000000   76.000000    8.000000    9.000000  512.329200

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    418 non-null    int64
#  1   name      418 non-null    object
#  2   sex       418 non-null    object
#  3   age       332 non-null    float64
#  4   sibsp     418 non-null    int64
#  5   parch     418 non-null    int64
#  6   ticket    418 non-null    object
#  7   fare      417 non-null    float64
#  8   cabin     91 non-null     object
#  9   embarked  418 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 32.8+ KB

# %%
data1.head()
# Out:
#    pclass                                          name     sex   age  sibsp  \
# 0       3                              Kelly, Mr. James    male  34.5      0
# 1       3              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2       2                     Myles, Mr. Thomas Francis    male  62.0      0
# 3       3                              Wirz, Mr. Albert    male  27.0      0
# 4       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
#
#    parch   ticket     fare cabin embarked
# 0      0   330911   7.8292   NaN        Q
# 1      0   363272   7.0000   NaN        S
# 2      0   240276   9.6875   NaN        Q
# 3      0   315154   8.6625   NaN        S
# 4      1  3101298  12.2875   NaN        S

# %%
data1.tail()
# Out:
#      pclass                          name     sex   age  sibsp  parch  \
# 413       3            Spector, Mr. Woolf    male   NaN      0      0
# 414       1  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415       3  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416       3           Ware, Mr. Frederick    male   NaN      0      0
# 417       3      Peter, Master. Michael J    male   NaN      1      1
#
#                  ticket      fare cabin embarked
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C

# %%
data1.isnull().sum()
# Out:
# pclass        0
# name          0
# sex           0
# age          86
# sibsp         0
# parch         0
# ticket        0
# fare          1
# cabin       327
# embarked      0
# dtype: int64

# %%
data1.dtypes
# Out:
# pclass        int64
# name         object
# sex          object
# age         float64
# sibsp         int64
# parch         int64
# ticket       object
# fare        float64
# cabin        object
# embarked     object
# dtype: object

# %%
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
data1['sex']=label_encoder.fit_transform(data1['sex'])
data1['sex'].value_counts()
# Out:
# 1    266
# 0    152
# Name: sex, dtype: int64

# %%
data1
# Out:
#      pclass                                          name  sex   age  sibsp  \
# 0         3                              Kelly, Mr. James    1  34.5      0
# 1         3              Wilkes, Mrs. James (Ellen Needs)    0  47.0      1
# 2         2                     Myles, Mr. Thomas Francis    1  62.0      0
# 3         3                              Wirz, Mr. Albert    1  27.0      0
# 4         3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0  22.0      1
# ..      ...                                           ...  ...   ...    ...
# 413       3                            Spector, Mr. Woolf    1   NaN      0
# 414       1                  Oliva y Ocana, Dona. Fermina    0  39.0      0
# 415       3                  Saether, Mr. Simon Sivertsen    1  38.5      0
# 416       3                           Ware, Mr. Frederick    1   NaN      0
# 417       3                      Peter, Master. Michael J    1   NaN      1
#
#      parch              ticket      fare cabin embarked
# ...

# %%
data1=data1.drop(['ticket','name','cabin'],axis=1)
data1
# Out:
#      pclass  sex   age  sibsp  parch      fare embarked
# 0         3    1  34.5      0      0    7.8292        Q
# 1         3    0  47.0      1      0    7.0000        S
# 2         2    1  62.0      0      0    9.6875        Q
# 3         3    1  27.0      0      0    8.6625        S
# 4         3    0  22.0      1      1   12.2875        S
# ..      ...  ...   ...    ...    ...       ...      ...
# 413       3    1   NaN      0      0    8.0500        S
# 414       1    0  39.0      0      0  108.9000        C
# 415       3    1  38.5      0      0    7.2500        S
# 416       3    1   NaN      0      0    8.0500        S
# 417       3    1   NaN      1      1   22.3583        C
#
# [418 rows x 7 columns]

# %%
data['age'].median()
# Out:
# 28.0

# %%
data1['age'].median()
# Out:
# 27.0

# %%
data['age']=data['age'].fillna(value=28)
data
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare embarked
# 0           0       3    1  22.0      1      0   7.2500        S
# 1           1       1    0  38.0      1      0  71.2833        C
# 2           1       3    0  26.0      0      0   7.9250        S
# 3           1       1    0  35.0      1      0  53.1000        S
# 4           0       3    1  35.0      0      0   8.0500        S
# ..        ...     ...  ...   ...    ...    ...      ...      ...
# 886         0       2    1  27.0      0      0  13.0000        S
# 887         1       1    0  19.0      0      0  30.0000        S
# 888         0       3    0  28.0      1      2  23.4500        S
# 889         1       1    1  26.0      0      0  30.0000        C
# 890         0       3    1  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
data1['age']=data1['age'].fillna(value=27)
data
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare embarked
# 0           0       3    1  22.0      1      0   7.2500        S
# 1           1       1    0  38.0      1      0  71.2833        C
# 2           1       3    0  26.0      0      0   7.9250        S
# 3           1       1    0  35.0      1      0  53.1000        S
# 4           0       3    1  35.0      0      0   8.0500        S
# ..        ...     ...  ...   ...    ...    ...      ...      ...
# 886         0       2    1  27.0      0      0  13.0000        S
# 887         1       1    0  19.0      0      0  30.0000        S
# 888         0       3    0  28.0      1      2  23.4500        S
# 889         1       1    1  26.0      0      0  30.0000        C
# 890         0       3    1  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
data.isnull().sum()
# Out:
# survived    0
# pclass      0
# sex         0
# age         0
# sibsp       0
# parch       0
# fare        0
# embarked    2
# dtype: int64

# %%
data1.isnull().sum()
# Out:
# pclass      0
# sex         0
# age         0
# sibsp       0
# parch       0
# fare        1
# embarked    0
# dtype: int64

# %%
data1['fare'].median()
# Out:
# 14.4542

# %%
data1['fare']=data1['fare'].fillna(value=14.4542)
data1
# Out:
#      pclass  sex   age  sibsp  parch      fare embarked
# 0         3    1  34.5      0      0    7.8292        Q
# 1         3    0  47.0      1      0    7.0000        S
# 2         2    1  62.0      0      0    9.6875        Q
# 3         3    1  27.0      0      0    8.6625        S
# 4         3    0  22.0      1      1   12.2875        S
# ..      ...  ...   ...    ...    ...       ...      ...
# 413       3    1  27.0      0      0    8.0500        S
# 414       1    0  39.0      0      0  108.9000        C
# 415       3    1  38.5      0      0    7.2500        S
# 416       3    1  27.0      0      0    8.0500        S
# 417       3    1  27.0      1      1   22.3583        C
#
# [418 rows x 7 columns]

# %%
data1.isnull().sum()
# Out:
# pclass      0
# sex         0
# age         0
# sibsp       0
# parch       0
# fare        0
# embarked    0
# dtype: int64

# %%
data['embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
g=data.groupby("survived")
g["embarked"].value_counts()
# Out:
# survived  embarked
# 0         S           427
#           C            75
#           Q            47
# 1         S           217
#           C            93
#           Q            30
# Name: embarked, dtype: int64

# %%
data['embarked']=data['embarked'].fillna(value='S')
data
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare embarked
# 0           0       3    1  22.0      1      0   7.2500        S
# 1           1       1    0  38.0      1      0  71.2833        C
# 2           1       3    0  26.0      0      0   7.9250        S
# 3           1       1    0  35.0      1      0  53.1000        S
# 4           0       3    1  35.0      0      0   8.0500        S
# ..        ...     ...  ...   ...    ...    ...      ...      ...
# 886         0       2    1  27.0      0      0  13.0000        S
# 887         1       1    0  19.0      0      0  30.0000        S
# 888         0       3    0  28.0      1      2  23.4500        S
# 889         1       1    1  26.0      0      0  30.0000        C
# 890         0       3    1  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
data.isnull().sum()
# Out:
# survived    0
# pclass      0
# sex         0
# age         0
# sibsp       0
# parch       0
# fare        0
# embarked    0
# dtype: int64

# %%
data1.isnull().sum()
# Out:
# pclass      0
# sex         0
# age         0
# sibsp       0
# parch       0
# fare        0
# embarked    0
# dtype: int64

# %%
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
data['embarked']=label_encoder.fit_transform(data['embarked'])
data['embarked'].value_counts()
# Out:
# 2    646
# 0    168
# 1     77
# Name: embarked, dtype: int64

# %%
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
data1['embarked']=label_encoder.fit_transform(data1['embarked'])
data1['embarked'].value_counts()
# Out:
# 2    270
# 0    102
# 1     46
# Name: embarked, dtype: int64

# %%
sns.countplot(data1['embarked'],hue=data1["pclass"])
plt.show()
# Out:
# /home/user/desktop/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data1.corr()
# Out:
#             pclass       sex       age     sibsp     parch      fare  embarked
# pclass    1.000000  0.108615 -0.467853  0.001087  0.018721 -0.577313  0.227983
# sex       0.108615  1.000000 -0.008035 -0.099943 -0.159120 -0.192036  0.076281
# age      -0.467853 -0.008035  1.000000 -0.071197 -0.043731  0.342357 -0.148051
# sibsp     0.001087 -0.099943 -0.071197  1.000000  0.306895  0.171912  0.052708
# parch     0.018721 -0.159120 -0.043731  0.306895  1.000000  0.230325  0.054577
# fare     -0.577313 -0.192036  0.342357  0.171912  0.230325  1.000000 -0.257624
# embarked  0.227983  0.076281 -0.148051  0.052708  0.054577 -0.257624  1.000000

# %%
data1.plot(x="pclass",y=["sibsp",'parch'],kind='bar')
plt.show()

# %%
correlation1=data1.corr()
correlation1['pclass'].sort_values(ascending=False)
# Out:
# pclass      1.000000
# embarked    0.227983
# sex         0.108615
# parch       0.018721
# sibsp       0.001087
# age        -0.467853
# fare       -0.577313
# Name: pclass, dtype: float64

# %%
sns.heatmap(data1.corr())
# Out:
# <AxesSubplot:>

# %%
correlation1['fare'].sort_values(ascending=False)
correlation1['fare']
# Out:
# pclass     -0.577313
# sex        -0.192036
# age         0.342357
# sibsp       0.171912
# parch       0.230325
# fare        1.000000
# embarked   -0.257624
# Name: fare, dtype: float64

# %%
data1.head(5)
# Out:
#    pclass  sex   age  sibsp  parch     fare  embarked
# 0       3    1  34.5      0      0   7.8292         1
# 1       3    0  47.0      1      0   7.0000         2
# 2       2    1  62.0      0      0   9.6875         1
# 3       3    1  27.0      0      0   8.6625         2
# 4       3    0  22.0      1      1  12.2875         2

# %%
data1['family']=data1['sibsp']+data1['parch']+1
data1=data1.drop(['sibsp','parch'],axis=1)
data1=data1.drop('embarked',axis=1)
data1
# Out:
#      pclass  sex   age      fare  family
# 0         3    1  34.5    7.8292       1
# 1         3    0  47.0    7.0000       2
# 2         2    1  62.0    9.6875       1
# 3         3    1  27.0    8.6625       1
# 4         3    0  22.0   12.2875       3
# ..      ...  ...   ...       ...     ...
# 413       3    1  27.0    8.0500       1
# 414       1    0  39.0  108.9000       1
# 415       3    1  38.5    7.2500       1
# 416       3    1  27.0    8.0500       1
# 417       3    1  27.0   22.3583       3
#
# [418 rows x 5 columns]

# %%
data1
# Out:
#      pclass  sex   age      fare  family
# 0         3    1  34.5    7.8292       1
# 1         3    0  47.0    7.0000       2
# 2         2    1  62.0    9.6875       1
# 3         3    1  27.0    8.6625       1
# 4         3    0  22.0   12.2875       3
# ..      ...  ...   ...       ...     ...
# 413       3    1  27.0    8.0500       1
# 414       1    0  39.0  108.9000       1
# 415       3    1  38.5    7.2500       1
# 416       3    1  27.0    8.0500       1
# 417       3    1  27.0   22.3583       3
#
# [418 rows x 5 columns]
